# %%
import pandas as pd

df = pd.read_csv('charging_points_world.csv')
df
# Out:
#         region    category           parameter mode               powertrain  \
# 0    Australia  Historical  EV charging points   EV  Publicly available fast
# 1    Australia  Historical  EV charging points   EV  Publicly available slow
# 2    Australia  Historical  EV charging points   EV  Publicly available fast
# 3    Australia  Historical  EV charging points   EV  Publicly available slow
# 4    Australia  Historical  EV charging points   EV  Publicly available fast
# ..         ...         ...                 ...  ...                      ...
# 599        USA  Historical  EV charging points   EV  Publicly available slow
# 600        USA  Historical  EV charging points   EV  Publicly available fast
# 601        USA  Historical  EV charging points   EV  Publicly available slow
# 602        USA  Historical  EV charging points   EV  Publicly available fast
# 603        USA  Historical  EV charging points   EV  Publicly available slow
#
#      year             unit     value
# 0    2017  charging points      40.0
# 1    2017  charging points     440.0
# 2    2018  charging points      61.0
# 3    2018  charging points     670.0
# 4    2019  charging points     250.0
# ..    ...              ...       ...
# 599  2020  charging points   82000.0
# 600  2021  charging points   22000.0
# 601  2021  charging points   92000.0
# 602  2022  charging points   28000.0
# 603  2022  charging points  100000.0
#
# [604 rows x 8 columns]

# %%
df.shape
# Out:
# (604, 8)

# %%
df.dtypes
# Out:
# region         object
# category       object
# parameter      object
# mode           object
# powertrain     object
# year            int64
# unit           object
# value         float64
# dtype: object

# %%
df['value'] = df['value'].astype(int)
df
# Out:
#         region    category           parameter mode               powertrain  \
# 0    Australia  Historical  EV charging points   EV  Publicly available fast
# 1    Australia  Historical  EV charging points   EV  Publicly available slow
# 2    Australia  Historical  EV charging points   EV  Publicly available fast
# 3    Australia  Historical  EV charging points   EV  Publicly available slow
# 4    Australia  Historical  EV charging points   EV  Publicly available fast
# ..         ...         ...                 ...  ...                      ...
# 599        USA  Historical  EV charging points   EV  Publicly available slow
# 600        USA  Historical  EV charging points   EV  Publicly available fast
# 601        USA  Historical  EV charging points   EV  Publicly available slow
# 602        USA  Historical  EV charging points   EV  Publicly available fast
# 603        USA  Historical  EV charging points   EV  Publicly available slow
#
#      year             unit   value
# 0    2017  charging points      40
# 1    2017  charging points     440
# 2    2018  charging points      61
# 3    2018  charging points     670
# 4    2019  charging points     250
# ..    ...              ...     ...
# 599  2020  charging points   82000
# 600  2021  charging points   22000
# 601  2021  charging points   92000
# 602  2022  charging points   28000
# 603  2022  charging points  100000
#
# [604 rows x 8 columns]

# %%
df.insert(0, 'id', range(1, 605))
df.reset_index(drop=True)
# Out:
#       id     region    category           parameter mode  \
# 0      1  Australia  Historical  EV charging points   EV
# 1      2  Australia  Historical  EV charging points   EV
# 2      3  Australia  Historical  EV charging points   EV
# 3      4  Australia  Historical  EV charging points   EV
# 4      5  Australia  Historical  EV charging points   EV
# ..   ...        ...         ...                 ...  ...
# 599  600        USA  Historical  EV charging points   EV
# 600  601        USA  Historical  EV charging points   EV
# 601  602        USA  Historical  EV charging points   EV
# 602  603        USA  Historical  EV charging points   EV
# 603  604        USA  Historical  EV charging points   EV
#
#                   powertrain  year             unit   value
# 0    Publicly available fast  2017  charging points      40
# 1    Publicly available slow  2017  charging points     440
# 2    Publicly available fast  2018  charging points      61
# 3    Publicly available slow  2018  charging points     670
# 4    Publicly available fast  2019  charging points     250
# ..                       ...   ...              ...     ...
# 599  Publicly available slow  2020  charging points   82000
# 600  Publicly available fast  2021  charging points   22000
# 601  Publicly available slow  2021  charging points   92000
# 602  Publicly available fast  2022  charging points   28000
# 603  Publicly available slow  2022  charging points  100000
#
# [604 rows x 9 columns]

# %%
df.to_csv('charging_points_world.csv', index=False)
