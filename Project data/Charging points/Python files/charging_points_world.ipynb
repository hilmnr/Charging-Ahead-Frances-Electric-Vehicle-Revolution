# %%
import pandas as pd

df = pd.read_csv('charging_points_world.csv')
df
# Out:
#       id     region    category           parameter mode  \
# 0      1  Australia  Historical  EV charging points   EV
# 1      2  Australia  Historical  EV charging points   EV
# 2      3  Australia  Historical  EV charging points   EV
# 3      4  Australia  Historical  EV charging points   EV
# 4      5  Australia  Historical  EV charging points   EV
# ..   ...        ...         ...                 ...  ...
# 599  600        USA  Historical  EV charging points   EV
# 600  601        USA  Historical  EV charging points   EV
# 601  602        USA  Historical  EV charging points   EV
# 602  603        USA  Historical  EV charging points   EV
# 603  604        USA  Historical  EV charging points   EV
#
#                   powertrain  year             unit   value
# 0    Publicly available fast  2017  charging points      40
# 1    Publicly available slow  2017  charging points     440
# 2    Publicly available fast  2018  charging points      61
# ...

# %%
df.shape
# Out:
# (604, 9)

# %%
df.dtypes
# Out:
# id             int64
# region        object
# category      object
# parameter     object
# mode          object
# powertrain    object
# year           int64
# unit          object
# value          int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 604 entries, 0 to 603
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          604 non-null    int64
#  1   region      604 non-null    object
#  2   category    604 non-null    object
#  3   parameter   604 non-null    object
#  4   mode        604 non-null    object
#  5   powertrain  604 non-null    object
#  6   year        604 non-null    int64
#  7   unit        604 non-null    object
#  8   value       604 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 42.6+ KB

# %%
df['powertrain'].replace({'Publicly available fast': 'Fast charging', 'Publicly available slow': 'Slow charging'}, inplace=True)

# %%
df.powertrain.unique()
# Out:
# array(['Fast charging', 'Slow charging'], dtype=object)

# %%
df
# Out:
#       id     region    category           parameter mode     powertrain  year  \
# 0      1  Australia  Historical  EV charging points   EV  Fast charging  2017
# 1      2  Australia  Historical  EV charging points   EV  Slow charging  2017
# 2      3  Australia  Historical  EV charging points   EV  Fast charging  2018
# 3      4  Australia  Historical  EV charging points   EV  Slow charging  2018
# 4      5  Australia  Historical  EV charging points   EV  Fast charging  2019
# ..   ...        ...         ...                 ...  ...            ...   ...
# 599  600        USA  Historical  EV charging points   EV  Slow charging  2020
# 600  601        USA  Historical  EV charging points   EV  Fast charging  2021
# 601  602        USA  Historical  EV charging points   EV  Slow charging  2021
# 602  603        USA  Historical  EV charging points   EV  Fast charging  2022
# 603  604        USA  Historical  EV charging points   EV  Slow charging  2022
#
#                 unit   value
# ...

# %%
df.to_csv('charging_points_world.csv', index=False)
