# %%
import requests
import json
import pandas as pd

# %%
api_url = 'https://data.enedis.fr/api/explore/v2.1/catalog/datasets/nombre-de-points-de-charge-accessibles-au-public-pour-100-000-habitants-par-dept/records?limit=95'

# %%
response = requests.get(api_url)
if response.status_code == 200:
    data = response.json()
    # Do something with the data, e.g., print it
    print(json.dumps(data, indent=2))
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# {
#   "total_count": 94,
#   "results": [
#     {
#       "departement": "Hautes-Alpes",
#       "code_departement": "05",
#       "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 259,
#       "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 28.0,
#       "code_region": "93"
#     },
#     {
#       "departement": "Eure-et-Loir",
#       "code_departement": "28",
#       "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 172,
#       "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 84.0,
#       "code_region": "24"
#     },
#     {
#       "departement": "Indre-et-Loire",
#       "code_departement": "37",
#       "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 198,
#       "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 42.0,
# ...

# %%
data = {
    "total_count": 94,
    "results": [
          {
      "departement": "Hautes Alpes",
      "code_departement": "05",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 259,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 28.0,
      "code_region": "93"
    },
    {
      "departement": "Eure et Loir",
      "code_departement": "28",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 172,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 84.0,
      "code_region": "24"
    },
    {
      "departement": "Indre et Loire",
      "code_departement": "37",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 198,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 42.0,
      "code_region": "24"
    },
    {
      "departement": "Loiret",
      "code_departement": "45",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 121,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 90.0,
      "code_region": "24"
    },
    {
      "departement": "Haute Marne",
      "code_departement": "52",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 223,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 56.0,
      "code_region": "44"
    },
    {
      "departement": "Savoie",
      "code_departement": "73",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 276,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 38.0,
      "code_region": "84"
    },
    {
      "departement": "Tarn et Garonne",
      "code_departement": "82",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 207,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 43.0,
      "code_region": "76"
    },
    {
      "departement": "Vosges",
      "code_departement": "88",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 194,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 189.0,
      "code_region": "44"
    },
    {
      "departement": "Ardeche",
      "code_departement": "07",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 151,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 17.0,
      "code_region": "84"
    },
    {
      "departement": "Eure",
      "code_departement": "27",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 217,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 103.0,
      "code_region": "28"
    },
    {
      "departement": "Haute Garonne",
      "code_departement": "31",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 190,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 52.0,
      "code_region": "76"
    },
    {
      "departement": "Ille et Vilaine",
      "code_departement": "35",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 106,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 34.0,
      "code_region": "53"
    },
    {
      "departement": "Jura",
      "code_departement": "39",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 109,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 91.0,
      "code_region": "27"
    },
    {
      "departement": "Lot",
      "code_departement": "46",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 147,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 27.0,
      "code_region": "76"
    },
    {
      "departement": "Manche",
      "code_departement": "50",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 162,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 32.0,
      "code_region": "28"
    },
    {
      "departement": "Mayenne",
      "code_departement": "53",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 138,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 42.0,
      "code_region": "52"
    },
    {
      "departement": "Nievre",
      "code_departement": "58",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 147,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 51.0,
      "code_region": "27"
    },
    {
      "departement": "Oise",
      "code_departement": "60",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 153,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 50.0,
      "code_region": "32"
    },
    {
      "departement": "Orne",
      "code_departement": "61",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 184,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 24.0,
      "code_region": "28"
    },
    {
      "departement": "Haut Rhin",
      "code_departement": "68",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 137,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 64.0,
      "code_region": "44"
    },
    {
      "departement": "Vendee",
      "code_departement": "85",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 158,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 66.0,
      "code_region": "52"
    },
    {
      "departement": "Vienne",
      "code_departement": "86",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 228,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 30.0,
      "code_region": "75"
    },
    {
      "departement": "Haute Vienne",
      "code_departement": "87",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 122,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 72.0,
      "code_region": "75"
    },
    {
      "departement": "Hauts de Seine",
      "code_departement": "92",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 166,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 43.0,
      "code_region": "11"
    },
    {
      "departement": "Aisne",
      "code_departement": "02",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 167,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 50.0,
      "code_region": "32"
    },
    {
      "departement": "Alpes Maritimes",
      "code_departement": "06",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 228,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 44.0,
      "code_region": "93"
    },
    {
      "departement": "Calvados",
      "code_departement": "14",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 220,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 52.0,
      "code_region": "28"
    },
    {
      "departement": "Correze",
      "code_departement": "19",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 210,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 124.0,
      "code_region": "75"
    },
    {
      "departement": "Creuse",
      "code_departement": "23",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 161,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 69.0,
      "code_region": "75"
    },
    {
      "departement": "Gard",
      "code_departement": "30",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 163,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 47.0,
      "code_region": "76"
    },
    {
      "departement": "Loir et Cher",
      "code_departement": "41",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 276,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 113.0,
      "code_region": "24"
    },
    {
      "departement": "Morbihan",
      "code_departement": "56",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 131,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 29.0,
      "code_region": "53"
    },
    {
      "departement": "Pyrenees Atlantiques",
      "code_departement": "64",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 132,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 30.0,
      "code_region": "75"
    },
    {
      "departement": "Rhone",
      "code_departement": "69",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 155,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 64.0,
      "code_region": "84"
    },
    {
      "departement": "Haute Savoie",
      "code_departement": "74",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 178,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 39.0,
      "code_region": "84"
    },
    {
      "departement": "Paris",
      "code_departement": "75",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 264,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 35.0,
      "code_region": "11"
    },
    {
      "departement": "Somme",
      "code_departement": "80",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 156,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 44.0,
      "code_region": "32"
    },
    {
      "departement": "Cotes dArmor",
      "code_departement": "22",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 170,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 34.0,
      "code_region": "53"
    },
    {
      "departement": "Nord",
      "code_departement": "59",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 171,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 63.0,
      "code_region": "32"
    },
    {
      "departement": "Hautes Pyrenees",
      "code_departement": "65",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 178,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 28.0,
      "code_region": "76"
    },
    {
      "departement": "Pyrenees Orientales",
      "code_departement": "66",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 161,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 49.0,
      "code_region": "76"
    },
    {
      "departement": "Saone et Loire",
      "code_departement": "71",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 150,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 63.0,
      "code_region": "27"
    },
    {
      "departement": "Seine Maritime",
      "code_departement": "76",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 155,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 71.0,
      "code_region": "28"
    },
    {
      "departement": "Vaucluse",
      "code_departement": "84",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 224,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 56.0,
      "code_region": "93"
    },
    {
      "departement": "Allier",
      "code_departement": "03",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 179,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 40.0,
      "code_region": "84"
    },
    {
      "departement": "Alpes de Haute Provence",
      "code_departement": "04",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 271,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 48.0,
      "code_region": "93"
    },
    {
      "departement": "Aube",
      "code_departement": "10",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 232,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 23.0,
      "code_region": "44"
    },
    {
      "departement": "Finistere",
      "code_departement": "29",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 151,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 30.0,
      "code_region": "53"
    },
    {
      "departement": "Indre",
      "code_departement": "36",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 183,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 27.0,
      "code_region": "24"
    },
    {
      "departement": "Landes",
      "code_departement": "40",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 201,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 67.0,
      "code_region": "75"
    },
    {
      "departement": "Lozere",
      "code_departement": "48",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 195,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 12.0,
      "code_region": "76"
    },
    {
      "departement": "Meuse",
      "code_departement": "55",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 158,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 41.0,
      "code_region": "44"
    },
    {
      "departement": "Moselle",
      "code_departement": "57",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 182,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 118.0,
      "code_region": "44"
    },
    {
      "departement": "Puy de Dome",
      "code_departement": "63",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 171,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 56.0,
      "code_region": "84"
    },
    {
      "departement": "Bas Rhin",
      "code_departement": "67",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 175,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 75.0,
      "code_region": "44"
    },
    {
      "departement": "Yvelines",
      "code_departement": "78",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 153,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 61.0,
      "code_region": "11"
    },
    {
      "departement": "Var",
      "code_departement": "83",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 190,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 56.0,
      "code_region": "93"
    },
    {
      "departement": "Val de Marne",
      "code_departement": "94",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 136,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 82.0,
      "code_region": "11"
    },
    {
      "departement": "Charente",
      "code_departement": "16",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 146,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 41.0,
      "code_region": "75"
    },
    {
      "departement": "Dordogne",
      "code_departement": "24",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 192,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 35.0,
      "code_region": "75"
    },
    {
      "departement": "Doubs",
      "code_departement": "25",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 118,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 64.0,
      "code_region": "27"
    },
    {
      "departement": "Drome",
      "code_departement": "26",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 220,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 54.0,
      "code_region": "84"
    },
    {
      "departement": "Gironde",
      "code_departement": "33",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 178,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 38.0,
      "code_region": "75"
    },
    {
      "departement": "Isere",
      "code_departement": "38",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 139,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 50.0,
      "code_region": "84"
    },
    {
      "departement": "Loire Atlantique",
      "code_departement": "44",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 133,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 50.0,
      "code_region": "52"
    },
    {
      "departement": "Maine et Loire",
      "code_departement": "49",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 150,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 43.0,
      "code_region": "52"
    },
    {
      "departement": "Meurthe et Moselle",
      "code_departement": "54",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 164,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 66.0,
      "code_region": "44"
    },
    {
      "departement": "Tarn",
      "code_departement": "81",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 160,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 45.0,
      "code_region": "76"
    },
    {
      "departement": "Yonne",
      "code_departement": "89",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 231,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 55.0,
      "code_region": "27"
    },
    {
      "departement": "Essonne",
      "code_departement": "91",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 119,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 35.0,
      "code_region": "11"
    },
    {
      "departement": "Seine Saint Denis",
      "code_departement": "93",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 77,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 42.0,
      "code_region": "11"
    },
    {
      "departement": "Ardennes",
      "code_departement": "08",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 389,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 59.0,
      "code_region": "44"
    },
    {
      "departement": "Ariege",
      "code_departement": "09",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 150,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 26.0,
      "code_region": "76"
    },
    {
      "departement": "Aude",
      "code_departement": "11",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 237,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 75.0,
      "code_region": "76"
    },
    {
      "departement": "Bouches du Rhona",
      "code_departement": "13",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 149,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 64.0,
      "code_region": "93"
    },
    {
      "departement": "Cantal",
      "code_departement": "15",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 89,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 38.0,
      "code_region": "84"
    },
    {
      "departement": "Gers",
      "code_departement": "32",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 143,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 37.0,
      "code_region": "76"
    },
    {
      "departement": "Haute Saone",
      "code_departement": "70",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 96,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 40.0,
      "code_region": "27"
    },
    {
      "departement": "Sarthe",
      "code_departement": "72",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 121,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 80.0,
      "code_region": "52"
    },
    {
      "departement": "Territoire de Belfort",
      "code_departement": "90",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 161,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 36.0,
      "code_region": "27"
    },
    {
      "departement": "Ain",
      "code_departement": "01",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 112,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 79.0,
      "code_region": "84"
    },
    {
      "departement": "Aveyron",
      "code_departement": "12",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 171,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 47.0,
      "code_region": "76"
    },
    {
      "departement": "Charente Maritime",
      "code_departement": "17",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 161,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 66.0,
      "code_region": "75"
    },
    {
      "departement": "Cher",
      "code_departement": "18",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 169,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 9.0,
      "code_region": "24"
    },
    {
      "departement": "Cote dOrd",
      "code_departement": "21",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 223,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 90.0,
      "code_region": "27"
    },
    {
      "departement": "Herault",
      "code_departement": "34",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 176,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 53.0,
      "code_region": "76"
    },
    {
      "departement": "Loire",
      "code_departement": "42",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 155,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 50.0,
      "code_region": "84"
    },
    {
      "departement": "Haute Loire",
      "code_departement": "43",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 106,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 45.0,
      "code_region": "84"
    },
    {
      "departement": "Lot et Garonne",
      "code_departement": "47",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 204,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 48.0,
      "code_region": "75"
    },
    {
      "departement": "Marne",
      "code_departement": "51",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 188,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 52.0,
      "code_region": "44"
    },
    {
      "departement": "Pas de Calais",
      "code_departement": "62",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 159,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 63.0,
      "code_region": "32"
    },
    {
      "departement": "Seine et Marne",
      "code_departement": "77",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 183,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 73.0,
      "code_region": "11"
    },
    {
      "departement": "Deux Sevres",
      "code_departement": "79",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 155,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 49.0,
      "code_region": "75"
    },
    {
      "departement": "Val dOise",
      "code_departement": "95",
      "nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 109,
      "evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants": 56.0,
      "code_region": "11"
    }

    ]
}
charging_points_per_departement = pd.DataFrame(data['results'])
charging_points_per_departement
# Out:
#        departement code_departement  \
# 0     Hautes Alpes               05
# 1     Eure et Loir               28
# 2   Indre et Loire               37
# 3           Loiret               45
# 4      Haute Marne               52
# ..             ...              ...
# 89           Marne               51
# 90   Pas de Calais               62
# 91  Seine et Marne               77
# 92     Deux Sevres               79
# 93       Val dOise               95
#
#     nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants  \
# 0                                                 259
# 1                                                 172
# 2                                                 198
# 3                                                 121
# 4                                                 223
# ..                                                ...
# 89                                                188
# 90                                                159
# ...

# %%
charging_points_per_departement.dtypes
# Out:
# departement                                                                                              object
# code_departement                                                                                         object
# nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants                                   int64
# evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants    float64
# code_region                                                                                              object
# dtype: object

# %%
charging_points_per_departement['evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants'] = charging_points_per_departement['evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants'].astype(int)
charging_points_per_departement['code_region '] = charging_points_per_departement['code_region'].astype(int)

# %%
charging_points_per_departement.dtypes
# Out:
# departement                                                                                             object
# code_departement                                                                                        object
# nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants                                  int64
# evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants     int64
# code_region                                                                                             object
# code_region                                                                                              int64
# dtype: object

# %%
charging_points_per_departement.shape
# Out:
# (94, 6)

# %%
charging_points_per_departement.insert(0, 'id', range(1, 95))
charging_points_per_departement.reset_index(drop=True)
# Out:
#     id     departement code_departement  \
# 0    1    Hautes Alpes               05
# 1    2    Eure et Loir               28
# 2    3  Indre et Loire               37
# 3    4          Loiret               45
# 4    5     Haute Marne               52
# ..  ..             ...              ...
# 89  90           Marne               51
# 90  91   Pas de Calais               62
# 91  92  Seine et Marne               77
# 92  93     Deux Sevres               79
# 93  94       Val dOise               95
#
#     nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants  \
# 0                                                 259
# 1                                                 172
# 2                                                 198
# 3                                                 121
# 4                                                 223
# ..                                                ...
# 89                                                188
# ...

# %%
charging_points_per_departement = charging_points_per_departement.drop('code_region', axis=1)
charging_points_per_departement
# Out:
#     id     departement code_departement  \
# 0    1    Hautes Alpes               05
# 1    2    Eure et Loir               28
# 2    3  Indre et Loire               37
# 3    4          Loiret               45
# 4    5     Haute Marne               52
# ..  ..             ...              ...
# 89  90           Marne               51
# 90  91   Pas de Calais               62
# 91  92  Seine et Marne               77
# 92  93     Deux Sevres               79
# 93  94       Val dOise               95
#
#     nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants  \
# 0                                                 259
# 1                                                 172
# 2                                                 198
# 3                                                 121
# 4                                                 223
# ..                                                ...
# 89                                                188
# ...

# %%
charging_points_per_departement = charging_points_per_departement.rename(
    columns={"nombre_de_points_de_charge_accessibles_au_public_pour_100_000_habitants":'nombre_pc_au_public_100_000_habitants',
            'evolution_sur_12_mois_de_la_densite_de_points_de_charge_accessibles_au_public_pour_100_000_habitants':'evolution_sur_12_mois'})
charging_points_per_departement
# Out:
#     id     departement code_departement  \
# 0    1    Hautes Alpes               05
# 1    2    Eure et Loir               28
# 2    3  Indre et Loire               37
# 3    4          Loiret               45
# 4    5     Haute Marne               52
# ..  ..             ...              ...
# 89  90           Marne               51
# 90  91   Pas de Calais               62
# 91  92  Seine et Marne               77
# 92  93     Deux Sevres               79
# 93  94       Val dOise               95
#
#     nombre_pc_au_public_100_000_habitants  evolution_sur_12_mois  code_region
# 0                                     259                     28            93
# 1                                     172                     84            24
# 2                                     198                     42            24
# 3                                     121                     90            24
# 4                                     223                     56            44
# ...

# %%
charging_points_per_departement.dtypes
# Out:
# id                                        int64
# departement                              object
# code_departement                         object
# nombre_pc_au_public_100_000_habitants     int64
# evolution_sur_12_mois                     int64
# code_region                               int64
# dtype: object

# %%
from unidecode import unidecode
charging_points_per_departement['departement'] = charging_points_per_departement['departement'].apply(unidecode)
charging_points_per_departement
# Out:
#     id     departement code_departement  \
# 0    1    Hautes Alpes               05
# 1    2    Eure et Loir               28
# 2    3  Indre et Loire               37
# 3    4          Loiret               45
# 4    5     Haute Marne               52
# ..  ..             ...              ...
# 89  90           Marne               51
# 90  91   Pas de Calais               62
# 91  92  Seine et Marne               77
# 92  93     Deux Sevres               79
# 93  94       Val dOise               95
#
#     nombre_pc_au_public_100_000_habitants  evolution_sur_12_mois  code_region
# 0                                     259                     28            93
# 1                                     172                     84            24
# 2                                     198                     42            24
# 3                                     121                     90            24
# 4                                     223                     56            44
# ...

# %%
charging_points_per_departement.to_csv('charging_points_per_departement.csv', index=False)
