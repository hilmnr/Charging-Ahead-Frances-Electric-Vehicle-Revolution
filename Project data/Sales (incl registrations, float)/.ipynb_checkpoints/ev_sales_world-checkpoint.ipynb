# %%
import pandas as pd

df = pd.read_csv('ev_sales_world.csv')
df
# Out:
#          region    category                      parameter  mode powertrain  \
# 0     Australia  Historical                       EV stock  Cars        BEV
# 1     Australia  Historical                 EV stock share  Cars         EV
# 2     Australia  Historical                 EV sales share  Cars         EV
# 3     Australia  Historical                       EV sales  Cars        BEV
# 4     Australia  Historical                       EV sales  Cars        BEV
# ...         ...         ...                            ...   ...        ...
# 2771      World  Historical           Oil displacement Mbd  Cars         EV
# 2772      World  Historical  Oil displacement, million lge  Cars         EV
# 2773      World  Historical                       EV sales  Cars        BEV
# 2774      World  Historical                 EV sales share  Cars         EV
# 2775      World  Historical                 EV stock share  Cars         EV
#
#       year                           unit         value
# ...

# %%
df.parameter.unique()
# Out:
# array(['EV stock', 'EV stock share', 'EV sales share', 'EV sales',
#        'Oil displacement Mbd', 'Oil displacement, million lge',
#        'Electricity demand'], dtype=object)

# %%
ev_sales_world = df[df['parameter'] == 'EV sales']
ev_sales_world.reset_index(drop=True)
# Out:
#         region    category parameter  mode powertrain  year      unit  \
# 0    Australia  Historical  EV sales  Cars        BEV  2011  Vehicles
# 1    Australia  Historical  EV sales  Cars        BEV  2012  Vehicles
# 2    Australia  Historical  EV sales  Cars       PHEV  2012  Vehicles
# 3    Australia  Historical  EV sales  Cars       PHEV  2013  Vehicles
# 4    Australia  Historical  EV sales  Cars        BEV  2013  Vehicles
# ..         ...         ...       ...   ...        ...   ...       ...
# 829      World  Historical  EV sales  Cars        BEV  2020  Vehicles
# 830      World  Historical  EV sales  Cars        BEV  2021  Vehicles
# 831      World  Historical  EV sales  Cars       PHEV  2021  Vehicles
# 832      World  Historical  EV sales  Cars       PHEV  2022  Vehicles
# 833      World  Historical  EV sales  Cars        BEV  2022  Vehicles
#
#          value
# 0         49.0
# 1        170.0
# 2         80.0
# 3        100.0
# 4        190.0
# ..         ...
# ...

# %%
ev_sales_world.shape
# Out:
# (834, 8)

# %%
ev_sales_world['value'] = ev_sales_world['value'].round().astype(int)
# Out:
# /var/folders/15/23jwx7dn6jd_qz_05y4dsg4w0000gn/T/ipykernel_31155/2703320922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_sales_world['value'] = ev_sales_world['value'].round().astype(int)

# %%
ev_sales_world.dtypes
# Out:
# region        object
# category      object
# parameter     object
# mode          object
# powertrain    object
# year           int64
# unit          object
# value          int64
# dtype: object

# %%
ev_sales_world
# Out:
#          region    category parameter  mode powertrain  year      unit  \
# 3     Australia  Historical  EV sales  Cars        BEV  2011  Vehicles
# 4     Australia  Historical  EV sales  Cars        BEV  2012  Vehicles
# 9     Australia  Historical  EV sales  Cars       PHEV  2012  Vehicles
# 10    Australia  Historical  EV sales  Cars       PHEV  2013  Vehicles
# 15    Australia  Historical  EV sales  Cars        BEV  2013  Vehicles
# ...         ...         ...       ...   ...        ...   ...       ...
# 2754      World  Historical  EV sales  Cars        BEV  2020  Vehicles
# 2760      World  Historical  EV sales  Cars        BEV  2021  Vehicles
# 2764      World  Historical  EV sales  Cars       PHEV  2021  Vehicles
# 2769      World  Historical  EV sales  Cars       PHEV  2022  Vehicles
# 2773      World  Historical  EV sales  Cars        BEV  2022  Vehicles
#
#         value country_id
# 3          49        001
# 4         170        002
# 9          80        003
# ...

# %%
cols = ev_sales_world.columns.tolist()
cols.remove('country_id')
cols.insert(0, 'country_id')
ev_sales_world = ev_sales_world[cols]
ev_sales_world.reset_index(drop=True)
# Out:
#     country_id     region    category parameter  mode powertrain  year  \
# 0          001  Australia  Historical  EV sales  Cars        BEV  2011
# 1          002  Australia  Historical  EV sales  Cars        BEV  2012
# 2          003  Australia  Historical  EV sales  Cars       PHEV  2012
# 3          004  Australia  Historical  EV sales  Cars       PHEV  2013
# 4          005  Australia  Historical  EV sales  Cars        BEV  2013
# ..         ...        ...         ...       ...   ...        ...   ...
# 829        830      World  Historical  EV sales  Cars        BEV  2020
# 830        831      World  Historical  EV sales  Cars        BEV  2021
# 831        832      World  Historical  EV sales  Cars       PHEV  2021
# 832        833      World  Historical  EV sales  Cars       PHEV  2022
# 833        834      World  Historical  EV sales  Cars        BEV  2022
#
#          unit    value
# 0    Vehicles       49
# 1    Vehicles      170
# 2    Vehicles       80
# ...

# %%
ev_sales_world.to_csv('ev_sales_world.csv', index=False)
