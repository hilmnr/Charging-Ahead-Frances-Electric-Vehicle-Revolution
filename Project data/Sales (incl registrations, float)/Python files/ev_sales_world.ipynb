# %%
import pandas as pd
df = pd.read_csv('ev_sales_world.csv')
df
# Out:
#          region    category                      parameter  mode powertrain  \
# 0     Australia  Historical                       EV stock  Cars        BEV
# 1     Australia  Historical                 EV stock share  Cars         EV
# 2     Australia  Historical                 EV sales share  Cars         EV
# 3     Australia  Historical                       EV sales  Cars        BEV
# 4     Australia  Historical                       EV sales  Cars        BEV
# ...         ...         ...                            ...   ...        ...
# 2771      World  Historical           Oil displacement Mbd  Cars         EV
# 2772      World  Historical  Oil displacement, million lge  Cars         EV
# 2773      World  Historical                       EV sales  Cars        BEV
# 2774      World  Historical                 EV sales share  Cars         EV
# 2775      World  Historical                 EV stock share  Cars         EV
#
#       year                           unit         value
# 0     2011                       Vehicles  4.900000e+01
# 1     2011                        percent  4.600000e-04
# 2     2011                        percent  6.500000e-03
# 3     2011                       Vehicles  4.900000e+01
# 4     2012                       Vehicles  1.700000e+02
# ...    ...                            ...           ...
# 2771  2022         Milion barrels per day  4.300000e-01
# 2772  2022  Oil displacement, million lge  2.500000e+04
# 2773  2022                       Vehicles  7.300000e+06
# 2774  2022                        percent  1.400000e+01
# 2775  2022                        percent  2.100000e+00
#
# [2776 rows x 8 columns]

# %%
df.shape
# Out:
# (2776, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2776 entries, 0 to 2775
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      2776 non-null   object
#  1   category    2776 non-null   object
#  2   parameter   2776 non-null   object
#  3   mode        2776 non-null   object
#  4   powertrain  2776 non-null   object
#  5   year        2776 non-null   int64
#  6   unit        2776 non-null   object
#  7   value       2776 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 173.6+ KB

# %%
df.dtypes
# Out:
# region         object
# category       object
# parameter      object
# mode           object
# powertrain     object
# year            int64
# unit           object
# value         float64
# dtype: object

# %%
ev_sales_world = df[df['parameter'] == 'EV sales']
ev_sales_world = df[df['powertrain'] == 'BEV']
ev_sales_world.reset_index(drop=True)
# Out:
#         region    category parameter  mode powertrain  year      unit  \
# 0    Australia  Historical  EV stock  Cars        BEV  2011  Vehicles
# 1    Australia  Historical  EV sales  Cars        BEV  2011  Vehicles
# 2    Australia  Historical  EV sales  Cars        BEV  2012  Vehicles
# 3    Australia  Historical  EV stock  Cars        BEV  2012  Vehicles
# 4    Australia  Historical  EV stock  Cars        BEV  2013  Vehicles
# ..         ...         ...       ...   ...        ...   ...       ...
# 881      World  Historical  EV sales  Cars        BEV  2020  Vehicles
# 882      World  Historical  EV sales  Cars        BEV  2021  Vehicles
# 883      World  Historical  EV stock  Cars        BEV  2021  Vehicles
# 884      World  Historical  EV stock  Cars        BEV  2022  Vehicles
# 885      World  Historical  EV sales  Cars        BEV  2022  Vehicles
#
#           value
# 0          49.0
# 1          49.0
# 2         170.0
# 3         220.0
# 4         410.0
# ..          ...
# 881   2000000.0
# 882   4600000.0
# 883  11000000.0
# 884  18000000.0
# 885   7300000.0
#
# [886 rows x 8 columns]

# %%
ev_sales_world.describe()
# Out:
#               year         value
# count   886.000000  8.860000e+02
# mean   2016.293454  1.840666e+05
# std       3.623792  9.903770e+05
# min    2010.000000  3.000000e+00
# 25%    2013.000000  6.400000e+02
# 50%    2016.000000  4.800000e+03
# 75%    2019.000000  3.475000e+04
# max    2022.000000  1.800000e+07

# %%
ev_sales_world['value'] = ev_sales_world['value'].round().astype(int)
# Out:
# /var/folders/15/23jwx7dn6jd_qz_05y4dsg4w0000gn/T/ipykernel_35843/2703320922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_sales_world['value'] = ev_sales_world['value'].round().astype(int)

# %%
ev_sales_world
# Out:
#          region    category parameter  mode powertrain  year      unit  \
# 0     Australia  Historical  EV stock  Cars        BEV  2011  Vehicles
# 3     Australia  Historical  EV sales  Cars        BEV  2011  Vehicles
# 4     Australia  Historical  EV sales  Cars        BEV  2012  Vehicles
# 7     Australia  Historical  EV stock  Cars        BEV  2012  Vehicles
# 12    Australia  Historical  EV stock  Cars        BEV  2013  Vehicles
# ...         ...         ...       ...   ...        ...   ...       ...
# 2754      World  Historical  EV sales  Cars        BEV  2020  Vehicles
# 2760      World  Historical  EV sales  Cars        BEV  2021  Vehicles
# 2765      World  Historical  EV stock  Cars        BEV  2021  Vehicles
# 2768      World  Historical  EV stock  Cars        BEV  2022  Vehicles
# 2773      World  Historical  EV sales  Cars        BEV  2022  Vehicles
#
#          value
# 0           49
# 3           49
# 4          170
# 7          220
# 12         410
# ...        ...
# 2754   2000000
# 2760   4600000
# 2765  11000000
# 2768  18000000
# 2773   7300000
#
# [886 rows x 8 columns]

# %%
ev_sales_world.dtypes
# Out:
# region        object
# category      object
# parameter     object
# mode          object
# powertrain    object
# year           int64
# unit          object
# value          int64
# dtype: object

# %%
cols.insert(0, 'country_id')

# %%
ev_sales_world
# Out:
#          region    category parameter  mode powertrain  year      unit  \
# 0     Australia  Historical  EV stock  Cars        BEV  2011  Vehicles
# 3     Australia  Historical  EV sales  Cars        BEV  2011  Vehicles
# 4     Australia  Historical  EV sales  Cars        BEV  2012  Vehicles
# 7     Australia  Historical  EV stock  Cars        BEV  2012  Vehicles
# 12    Australia  Historical  EV stock  Cars        BEV  2013  Vehicles
# ...         ...         ...       ...   ...        ...   ...       ...
# 2754      World  Historical  EV sales  Cars        BEV  2020  Vehicles
# 2760      World  Historical  EV sales  Cars        BEV  2021  Vehicles
# 2765      World  Historical  EV stock  Cars        BEV  2021  Vehicles
# 2768      World  Historical  EV stock  Cars        BEV  2022  Vehicles
# 2773      World  Historical  EV sales  Cars        BEV  2022  Vehicles
#
#          value
# 0           49
# 3           49
# 4          170
# 7          220
# 12         410
# ...        ...
# 2754   2000000
# 2760   4600000
# 2765  11000000
# 2768  18000000
# 2773   7300000
#
# [886 rows x 8 columns]

# %%
default_value = 0
ev_sales_world.insert(0, 'country_id', range(1, len(ev_sales_world) + 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 default_value = 0
# ----> 2 ev_sales_world.insert(0, 'country_id', range(1, len(ev_sales_world) + 1))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4817, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4811     raise ValueError(
#    4812         "Cannot specify 'allow_duplicates=True' when "
#    4813         "'self.flags.allows_duplicate_labels' is False."
#    4814     )
#    4815 if not allow_duplicates and column in self.columns:
#    4816     # Should this be a different kind of error??
# -> 4817     raise ValueError(f"cannot insert {column}, already exists")
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
#
# ValueError: cannot insert country_id, already exists

# %%
ev_sales_world.reset_index(drop=True, inplace=True)
ev_sales_world
# Out:
#      country_id     region    category parameter  mode powertrain  year  \
# 0             1  Australia  Historical  EV stock  Cars        BEV  2011
# 1             2  Australia  Historical  EV sales  Cars        BEV  2011
# 2             3  Australia  Historical  EV sales  Cars        BEV  2012
# 3             4  Australia  Historical  EV stock  Cars        BEV  2012
# 4             5  Australia  Historical  EV stock  Cars        BEV  2013
# ..          ...        ...         ...       ...   ...        ...   ...
# 881         882      World  Historical  EV sales  Cars        BEV  2020
# 882         883      World  Historical  EV sales  Cars        BEV  2021
# 883         884      World  Historical  EV stock  Cars        BEV  2021
# 884         885      World  Historical  EV stock  Cars        BEV  2022
# 885         886      World  Historical  EV sales  Cars        BEV  2022
#
#          unit     value
# 0    Vehicles        49
# 1    Vehicles        49
# 2    Vehicles       170
# 3    Vehicles       220
# 4    Vehicles       410
# ..        ...       ...
# 881  Vehicles   2000000
# 882  Vehicles   4600000
# 883  Vehicles  11000000
# 884  Vehicles  18000000
# 885  Vehicles   7300000
#
# [886 rows x 9 columns]

# %%
ev_sales_world.to_csv('ev_sales_world.csv', index=False)
